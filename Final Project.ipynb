# %% [markdown]
# # Fighting Fire in California

# %% [markdown]
# ### Research question:
# What external factors influence average fire salary?
#
# ### Data:
# https://transparentcalifornia.com/agencies/salaries/#counties

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import os
import glob

# %%
# note to self
# get description of each county
    # put into array? use glob package
    # see which fire positions there are
    
# append all csvs into one huge df
    # put all positions involving fire together, vs all positions total
    # still separate by county

# %%
# put all csv names in array
os.chdir('data/counties') 
files = glob.glob('*.csv')

#testing three counties for now only
test_files = ['los-angeles-county-2016.csv',
 'san-mateo-county-2016.csv',
 'san-diego-county-2016.csv']

files
# Out:
# ['los-angeles-county-2016.csv',
#  'san-mateo-county-2016.csv',
#  'san-diego-county-2016.csv',
#  'modoc-county-2016.csv',
#  'mono-county-2016.csv',
#  'mendocino-county-2016.csv',
#  'alameda-county-2016.csv',
#  'trinity-county-2016.csv',
#  'san-francisco-2016.csv',
#  'solano-county-2016.csv',
#  'orange-county-2016.csv',
#  'combined_csv.csv',
#  'merced-county-2016.csv',
#  'mariposa-county-2016.csv',
#  'del-norte-county-2016.csv',
#  'santa-cruz-county-2016.csv',
#  'sutter-county-2016.csv',
#  'colusa-county-2016.csv',
#  'inyo-county-2016.csv',
#  'imperial-county-2016.csv',
#  'san-joaquin-county-2016.csv',
#  'el-dorado-county-2016.csv',
#  'monterey-county-2016.csv',
#  'kern-county-2016.csv',
#  'riverside-county-2016.csv',
#  'san-benito-county-2016.csv',
#  'humboldt-county-2016.csv',
#  'santa-clara-county-2016.csv',
#  'fresno-county-2016.csv',
#  'san-bernardino-county-2016.csv',
#  'plumas-county-2016.csv',
#  'nevada-county-2016.csv',
# ...

# %%
#combine all csvs into one big df
combined_csv = pd.concat([pd.read_csv(f) for f in test_files])  #changes test_files to files later
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
combined_csv
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
#            Employee Name                                          Job Title  \
# 0  Helen N Robbins-Meyer                       Chief Administrative Officer
# 1    Michael S Krelstein            Clinic Director, Mental Health Services
# 2       Bonnie M Dumanis                                  District Attorney
# 3    Thomas E Montgomery                                     County Counsel
# 4        Donald F Steuer  Assistant Chief Administrative Officer/Chief O...
#
#    Base Pay  Overtime Pay  Other Pay   Benefits  Total Pay  \
# 0  304640.0           0.0    12100.0  138159.11   316740.0
# 1  270962.4           0.0        0.0  114295.20   270962.4
# 2  264456.0           0.0    12000.0  101466.16   276456.0
# ...

# %%
combined_csv = combined_csv.drop(columns=['Base Pay', 'Overtime Pay', 'Other Pay', 'Benefits', 'Year', 'Notes', 'Status'])
combined_csv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c1313bbcf319> in <module>
# ----> 1 combined_csv = combined_csv.drop(columns=['Base Pay', 'Overtime Pay', 'Other Pay', 'Benefits', 'Year', 'Notes', 'Status'])
#       2 combined_csv
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ...
